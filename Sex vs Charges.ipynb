# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.read_csv('insuranceCleanedFinal.csv')
df.head()
# Out:
#    age     sex    bmi  children smoker     region   charges
# 0   19  female  27.90         0    yes  southwest  16884.92
# 1   18    male  33.77         1     no  southeast   1725.55
# 2   28    male  33.00         3     no  southeast   4449.46
# 3   33    male  22.70         0     no  northwest  21984.47
# 4   32    male  28.88         0     no  northwest   3866.86

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X
# Out:
#       male
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 1326     1
# 1327     0
# 1328     0
# 1329     0
# 1330     0
#
# [1331 rows x 1 columns]

# %%
y
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1326    10600.55
# 1327     2205.98
# 1328     1629.83
# 1329     2007.94
# 1330    29141.36
# Name: charges, Length: 1331, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2)

# %%
len(X_train)
# Out:
# 1064

# %%
len(X_test)
# Out:
# 267

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %% [markdown]
# # Train model

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([13796.07254302, 12071.2832902 , 13796.07254302, 12071.2832902 ,
#        13796.07254302, 13796.07254302, 12071.2832902 , 13796.07254302,
#        13796.07254302, 12071.2832902 , 12071.2832902 , 13796.07254302,
#        12071.2832902 , 12071.2832902 , 12071.2832902 , 12071.2832902 ,
#        13796.07254302, 13796.07254302, 13796.07254302, 12071.2832902 ,
#        12071.2832902 , 13796.07254302, 12071.2832902 , 13796.07254302,
#        13796.07254302, 13796.07254302, 13796.07254302, 13796.07254302,
#        13796.07254302, 13796.07254302, 13796.07254302, 13796.07254302,
#        13796.07254302, 13796.07254302, 13796.07254302, 13796.07254302,
#        13796.07254302, 13796.07254302, 13796.07254302, 13796.07254302,
#        13796.07254302, 12071.2832902 , 13796.07254302, 13796.07254302,
#        12071.2832902 , 12071.2832902 , 12071.2832902 , 12071.2832902 ,
#        13796.07254302, 13796.07254302, 12071.2832902 , 13796.07254302,
# ...

# %%
y_test
# Out:
# 712     12146.97
# 1298     2464.62
# 1066    39871.70
# 664     40003.33
# 940     12982.87
#           ...
# 493     17942.11
# 1329     2007.94
# 751     17128.43
# 440     37079.37
# 775      5934.38
# Name: charges, Length: 267, dtype: float64

# %% [markdown]
# # Check accuracy of Model

# %%
clf.score(X_test, y_test)
# Out:
# -0.00819786029248859

# %%
import pandas as pd

# %%
sex= pd.read_csv('insuranceCleanedFinal.csv')
ohe_sex = pd.get_dummies(sex[['sex']])
print(ohe_sex.to_string())
# Out:
#       sex_female  sex_male
# 0              1         0
# 1              0         1
# 2              0         1
# 3              0         1
# 4              0         1
# 5              1         0
# 6              1         0
# 7              1         0
# 8              0         1
# 9              1         0
# 10             0         1
# 11             1         0
# 12             0         1
# 13             1         0
# 14             0         1
# 15             0         1
# 16             1         0
# 17             0         1
# 18             0         1
# 19             0         1
# 20             1         0
# 21             1         0
# 22             0         1
# 23             1         0
# 24             0         1
# 25             1         0
# 26             1         0
# 27             1         0
# 28             0         1
# 29             0         1
# 30             0         1
# 31             1         0
# 32             1         0
# ...

# %%
dummies = pd.get_dummies(df.sex)
dummies
# Out:
#       female  male
# 0          1     0
# 1          0     1
# 2          0     1
# 3          0     1
# 4          0     1
# ...      ...   ...
# 1326       0     1
# 1327       1     0
# 1328       1     0
# 1329       1     0
# 1330       1     0
#
# [1331 rows x 2 columns]

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#       age     sex    bmi  children smoker     region   charges  female  male
# 0      19  female  27.90         0    yes  southwest  16884.92       1     0
# 1      18    male  33.77         1     no  southeast   1725.55       0     1
# 2      28    male  33.00         3     no  southeast   4449.46       0     1
# 3      33    male  22.70         0     no  northwest  21984.47       0     1
# 4      32    male  28.88         0     no  northwest   3866.86       0     1
# ...   ...     ...    ...       ...    ...        ...       ...     ...   ...
# 1326   50    male  30.97         3     no  northwest  10600.55       0     1
# 1327   18  female  31.92         0     no  northeast   2205.98       1     0
# 1328   18  female  36.85         0     no  southeast   1629.83       1     0
# 1329   21  female  25.80         0     no  southwest   2007.94       1     0
# 1330   61  female  29.07         0    yes  northwest  29141.36       1     0
#
# [1331 rows x 9 columns]

# %%
final = merged.drop(['sex','female','age','bmi','smoker','region','children'], axis = 'columns')
final
# Out:
#        charges  male
# 0     16884.92     0
# 1      1725.55     1
# 2      4449.46     1
# 3     21984.47     1
# 4      3866.86     1
# ...        ...   ...
# 1326  10600.55     1
# 1327   2205.98     0
# 1328   1629.83     0
# 1329   2007.94     0
# 1330  29141.36     0
#
# [1331 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
X= final.drop('charges', axis='columns')

# %%
X
# Out:
#       male
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 1326     1
# 1327     0
# 1328     0
# 1329     0
# 1330     0
#
# [1331 rows x 1 columns]

# %%
y = final.charges 
y
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1326    10600.55
# 1327     2205.98
# 1328     1629.83
# 1329     2007.94
# 1330    29141.36
# Name: charges, Length: 1331, dtype: float64

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X,y, test_size= 0.2, random_state =1)

# %%
Xtest
# Out:
#       male
# 1258     0
# 325      0
# 930      1
# 1020     0
# 1154     0
# ...    ...
# 8        1
# 241      0
# 283      0
# 315      1
# 452      1
#
# [267 rows x 1 columns]

# %%
ytest
# Out:
# 1258    10370.91
# 325      3561.89
# 930      4673.39
# 1020     8569.86
# 1154     3989.84
#           ...
# 8        6406.41
# 241     35160.13
# 283      9625.92
# 315      8835.26
# 452      1769.53
# Name: charges, Length: 267, dtype: float64

# %%
model.fit(Xtrain,ytrain)
# Out:
# LinearRegression()

# %%
print(model.score(Xtest,ytest))
print("Model coefficients:", model.coef_)
print("Model intercept:", model.intercept_)
# Out:
# 0.0012257999418274768
# Model coefficients: [985.17767364]
# Model intercept: 12732.162730769232

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
y_pred = model.predict(Xtest)

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error (MSE): 147801577.31970033
# Mean Absolute Error (MAE): 9275.296745538664
