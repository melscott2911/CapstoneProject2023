# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.age.unique()
for col in df:
  print(df[col].unique())
# Out:
# [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
# ['female' 'male']
# [27.9   33.77  33.    22.705 28.88  25.74  33.44  27.74  29.83  25.84
#  26.22  26.29  34.4   39.82  42.13  24.6   30.78  23.845 40.3   35.3
#  36.005 32.4   34.1   31.92  28.025 27.72  23.085 32.775 17.385 36.3
#  35.6   26.315 28.6   28.31  36.4   20.425 32.965 20.8   36.67  39.9
#  26.6   36.63  21.78  30.8   37.05  37.3   38.665 34.77  24.53  35.2
#  35.625 33.63  28.    34.43  28.69  36.955 31.825 31.68  22.88  37.335
#  27.36  33.66  24.7   25.935 22.42  28.9   39.1   36.19  23.98  24.75
#  28.5   28.1   32.01  27.4   34.01  29.59  35.53  39.805 26.885 38.285
#  37.62  41.23  34.8   22.895 31.16  27.2   26.98  39.49  24.795 31.3
#  38.28  19.95  19.3   31.6   25.46  30.115 29.92  27.5   28.4   30.875
#  27.94  35.09  29.7   35.72  32.205 28.595 49.06  27.17  23.37  37.1
# ...

# %%
df['age'].nunique()
# Out:
# 47

# %%
df['sex'].nunique()
# Out:
# 2

# %%
df['bmi'].nunique()
# Out:
# 548

# %%
df['children'].nunique()
# Out:
# 6

# %%
df['smoker'].nunique()
# Out:
# 2

# %%
df['region'].nunique()
# Out:
# 4

# %%
df['charges'].nunique()
print(df['charges'].value_counts())
# Out:
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 23.2 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 30.1 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#   Using cached kiwisolver-1.4.4-cp310-cp310-macosx_10_9_x86_64.whl (65 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.8 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('insurance.csv')

df.plot(kind = 'scatter', x = 'age', y = 'charges', color=['orange'])

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('insurance.csv')

df.plot(kind = 'scatter', x = 'bmi', y = 'charges',color=['green'])

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('insurance.csv')

df.plot(kind = 'scatter', x = 'smoker', y = 'charges')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('insurance.csv')

df.plot(kind = 'scatter', x = 'children', y = 'charges',color=['pink'])

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('insurance.csv')

df.plot(kind = 'scatter', x = 'region', y = 'charges',color=['purple'])

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('insurance.csv')

df.plot(kind = 'scatter', x = 'sex', y = 'charges',color=['yellow'])

plt.show()

# %%
above_50000 = df[df["charges"] > 50000]

above_50000
# Out:
#       age     sex     bmi  children smoker     region      charges
# 34     28    male  36.400         1    yes  southwest  51194.55914
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 819    33  female  35.530         0    yes  northwest  55135.40209
# 1146   60    male  32.800         0    yes  southwest  52590.82939
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 1300   45    male  30.360         0    yes  southeast  62592.87309

# %%
df.drop(index=[34,543,577,819,1146,1230,1300])
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1331 rows x 7 columns]

# %%
df1 = df[df.charges < 50000]
df1.to_csv('insuranceCleaned.csv')

# %%
df1 = pd.read_csv('insuranceCleaned.csv')

# %%
df1
# Out:
#       Unnamed: 0  age     sex     bmi  children smoker     region      charges
# 0              0   19  female  27.900         0    yes  southwest  16884.92400
# 1              1   18    male  33.770         1     no  southeast   1725.55230
# 2              2   28    male  33.000         3     no  southeast   4449.46200
# 3              3   33    male  22.705         0     no  northwest  21984.47061
# 4              4   32    male  28.880         0     no  northwest   3866.85520
# ...          ...  ...     ...     ...       ...    ...        ...          ...
# 1326        1333   50    male  30.970         3     no  northwest  10600.54830
# 1327        1334   18  female  31.920         0     no  northeast   2205.98080
# 1328        1335   18  female  36.850         0     no  southeast   1629.83350
# 1329        1336   21  female  25.800         0     no  southwest   2007.94500
# 1330        1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1331 rows x 8 columns]

# %%
df1.round(2)
# Out:
#       Unnamed: 0  age     sex    bmi  children smoker     region   charges
# 0              0   19  female  27.90         0    yes  southwest  16884.92
# 1              1   18    male  33.77         1     no  southeast   1725.55
# 2              2   28    male  33.00         3     no  southeast   4449.46
# 3              3   33    male  22.70         0     no  northwest  21984.47
# 4              4   32    male  28.88         0     no  northwest   3866.86
# ...          ...  ...     ...    ...       ...    ...        ...       ...
# 1326        1333   50    male  30.97         3     no  northwest  10600.55
# 1327        1334   18  female  31.92         0     no  northeast   2205.98
# 1328        1335   18  female  36.85         0     no  southeast   1629.83
# 1329        1336   21  female  25.80         0     no  southwest   2007.94
# 1330        1337   61  female  29.07         0    yes  northwest  29141.36
#
# [1331 rows x 8 columns]

# %%
df2 = df1.round({"bmi":2, "charges":2})
df2.to_csv('insuranceCleanedFinal.csv')

# %%
df2 = pd.read_csv('insuranceCleanedFinal.csv')

# %%
df2
# Out:
#       Unnamed: 0.1  Unnamed: 0  age     sex    bmi  children smoker  \
# 0                0           0   19  female  27.90         0    yes
# 1                1           1   18    male  33.77         1     no
# 2                2           2   28    male  33.00         3     no
# 3                3           3   33    male  22.70         0     no
# 4                4           4   32    male  28.88         0     no
# ...            ...         ...  ...     ...    ...       ...    ...
# 1326          1326        1333   50    male  30.97         3     no
# 1327          1327        1334   18  female  31.92         0     no
# 1328          1328        1335   18  female  36.85         0     no
# 1329          1329        1336   21  female  25.80         0     no
# 1330          1330        1337   61  female  29.07         0    yes
#
#          region   charges
# 0     southwest  16884.92
# 1     southeast   1725.55
# 2     southeast   4449.46
# 3     northwest  21984.47
# ...
