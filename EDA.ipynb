# %%
import pandas as pd

import numpy as np

df = pd.read_csv('insuranceCleanedFinal.csv')
df.head()
# Out:
#    age     sex    bmi  children smoker     region   charges
# 0   19  female  27.90         0    yes  southwest  16884.92
# 1   18    male  33.77         1     no  southeast   1725.55
# 2   28    male  33.00         3     no  southeast   4449.46
# 3   33    male  22.70         0     no  northwest  21984.47
# 4   32    male  28.88         0     no  northwest   3866.86

# %% [markdown]
# # Univariate Analysis

# %%
#calculate mean of 'age'
df['age'].mean()
# Out:
# 39.20702541106129

# %%
#calculate median of 'age' 
df['age'].median()
# Out:
# 39.0

# %%
#calculate standard deviation of 'age' 
df['age'].std()
# Out:
# 14.049960379216154

# %%
#calculate mean of 'bmi'
df['bmi'].mean()
# Out:
# 30.66339686098655

# %%
#calculate median of 'bmi' 
df['bmi'].median()
# Out:
# 30.4

# %%
#calculate standard deviation of 'bmi' 
df['bmi'].std()
# Out:
# 6.098186911679014

# %%
#calculate mean of 'children'
df['children'].mean()
# Out:
# 1.0949177877429

# %%
#calculate median of 'children' 
df['children'].median()
# Out:
# 1.0

# %%
#calculate standard deviation of 'bmi' 
df['children'].std()
# Out:
# 1.205492739781914

# %%
#calculate mean of 'charges'
df['charges'].mean()
# Out:
# 13270.422265141257

# %%
#calculate median of 'charges' 
df['charges'].median()
# Out:
# 9382.033

# %%
#calculate standard deviation of 'bmi' 
df['charges'].std()
# Out:
# 12110.011236694001

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
import matplotlib.pyplot as plt

df.hist(column='age', grid=False, edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'age'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

df.hist(column='bmi', grid=False, edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'bmi'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

df.hist(column='children', grid=False, edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'children'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

df.hist(column='charges', grid=False, edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'charges'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

df.hist(column='age', grid=False, edgecolor='black')

# %% [markdown]
# # Multivariate Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('insuranceCleanedFinal.csv')

df.plot(kind = 'scatter', x = 'age', y = 'charges', color=['orange'])

plt.show()

# %%
df = pd.read_csv('insuranceCleanedFinal.csv')

df.plot(kind = 'scatter', x = 'bmi', y = 'charges',color=['green'])

plt.show()

# %%
df = pd.read_csv('insuranceCleanedFinal.csv')

df.plot(kind = 'scatter', x = 'children', y = 'charges',color=['pink'])

plt.show()

# %%
df = pd.read_csv('insuranceCleanedFinal.csv')

df.plot(kind = 'scatter', x = 'region', y = 'charges',color=['purple'])

plt.show()

# %%
df = pd.read_csv('insuranceCleanedFinal.csv')

df.plot(kind = 'scatter', x = 'sex', y = 'charges',color=['yellow'])

plt.show()

# %%
df = pd.read_csv('insuranceCleanedFinal.csv')

df.plot(kind = 'scatter', x = 'smoker', y = 'charges', color=['black'])

plt.show()

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
# calculate correlation matrix
corr = df.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# /var/folders/sd/0nzzwspj72zb2_mv_qh4r8tm0000gn/T/ipykernel_48794/3334069724.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()# plot the heatmap
# <Axes: >

# %%
sns.relplot(x='bmi', y='charges', hue='sex', data=df)

# %%
sns.relplot(x='bmi', y='charges', hue='region', data=df)

# %%
sns.relplot(x='age', y='charges', hue='sex', data=df)

# %%
sns.relplot(x='age', y='charges', hue='region', data=df)

# %% [markdown]
# # Regression Statistics

# %% [markdown]
# ## Age & Charges

# %% [markdown]
# ![LR Age_Charges.png](attachment:c010059b-fe4e-4ca1-8913-8528acfe7494.png)

# %% [markdown]
# ## Children & Charges

# %% [markdown]
# ![LR Children_Charges.png](attachment:be8ff181-ffd4-44cc-be2c-ffe9037d7c16.png)

# %% [markdown]
# ## BMI & Charges

# %% [markdown]
# ![LR BMI_Charges.png](attachment:be6d856b-0de2-43e7-b2de-eead9fc49766.png)
